# %% [markdown]
# Crear una matriz de Numpy aleatoria de 4 dimensiones y un size de 1200000

# %%
import numpy as np

matriz_4d = np.random.random(size=(10, 20, 30, 200))
print("Shape:", matriz_4d.shape)
print("Size:", matriz_4d.size)
# Out:
# Matriz 4D creada
# Shape: (10, 20, 30, 200)
# Size: 1200000

# %% [markdown]
# Crear una copia de la matriz creada anteriormente.

# %%
matriz_3d = matriz_4d[0, :, :, :].copy()
print("Shape 3D:", matriz_3d.shape)
print("Size:", matriz_3d.size)
# Out:
# Shape 3D: (20, 30, 200)
# Size: 120000

# %% [markdown]
# Atributos de la matriz anterior

# %%
print("Número de dimensiones:", matriz_3d.ndim)
print("Forma:                ", matriz_3d.shape)
print("Tamaño total:         ", matriz_3d.size)
print("Tipo de dato:         ", matriz_3d.dtype)
print("Bytes por elemento:   ", matriz_3d.itemsize)
print("Bytes totales:        ", matriz_3d.nbytes)
# Out:
# Número de dimensiones: 3
# Forma:                 (20, 30, 200)
# Tamaño total:          120000
# Tipo de dato:          float64
# Bytes por elemento:    8
# Bytes totales:         960000

# %% [markdown]
# Pasar a 2D con reshape

# %%
matriz_2d = matriz_3d.reshape(600, 200)
print("Shape 2D:", matriz_2d.shape)
print("Dimensiones:", matriz_2d.ndim)
# Out:
# Shape 2D: (600, 200)
# Dimensiones: 2

# %% [markdown]
# Funcion que convierte la amtriz 2D a DataFrame de Pandas

# %%
import numpy as np
import pandas as pd

def matriz_a_dataframe(matriz):
    columnas = [f"col_{i}" for i in range(matriz.shape[1])]
    df = pd.DataFrame(matriz, columns=columnas)
    return df

df = matriz_a_dataframe(matriz_2d)
print("Shape:", df.shape)
print(df.head())
# Out:
# Shape: (600, 200)
#       col_0     col_1     col_2     col_3     col_4     col_5     col_6  \
# 0  0.147175  0.284444  0.227554  0.754144  0.719455  0.643691  0.488943
# 1  0.632204  0.462730  0.969195  0.151623  0.129489  0.178347  0.707570
# 2  0.798018  0.372054  0.904681  0.777051  0.827194  0.588282  0.895126
# 3  0.813335  0.004336  0.174881  0.158199  0.048468  0.517850  0.688178
# 4  0.218420  0.518767  0.354677  0.261420  0.188187  0.801532  0.161746
#
#       col_7     col_8     col_9  ...   col_190   col_191   col_192   col_193  \
# 0  0.470689  0.258845  0.066275  ...  0.918768  0.639788  0.596103  0.420819
# 1  0.139021  0.573762  0.992979  ...  0.923997  0.420740  0.971774  0.454579
# 2  0.742133  0.445401  0.704807  ...  0.554247  0.918614  0.627846  0.786718
# 3  0.564638  0.538053  0.219092  ...  0.014955  0.936443  0.536553  0.585828
# 4  0.966382  0.332510  0.765584  ...  0.331258  0.010181  0.784920  0.314040
#
#     col_194   col_195   col_196   col_197   col_198   col_199
# 0  0.047796  0.405391  0.267329  0.759701  0.910376  0.466994
# 1  0.648390  0.719296  0.423385  0.204277  0.713327  0.198751
# 2  0.537209  0.303694  0.756849  0.773336  0.388071  0.659328
# 3  0.470140  0.943389  0.686069  0.713140  0.147928  0.716421
# 4  0.654116  0.757585  0.777029  0.626035  0.873214  0.130245
#
# [5 rows x 200 columns]

# %% [markdown]
# Funcion para cargar archivos tipo .mat y .csv

# %%
import numpy as np
import pandas as pd
import scipy.io

def cargar_archivo(ruta):
    if ruta.endswith('.csv'):
        datos = pd.read_csv(ruta)
        print("Archivo CSV cargado")
        print("Shape:", datos.shape)
        print(datos.head())
        return datos

    elif ruta.endswith('.mat'):
        datos = scipy.io.loadmat(ruta)
        llaves = [k for k in datos.keys() if not k.startswith('__')]
        print("Archivo mat cargado")
        print("Variables encontradas:", llaves)
        return datos

    else:
        print("Use archivos .mat o .csv")
        return None

# %% [markdown]
# Funciones de operaciones con NumPy a lo largo de un eje

# %%
import numpy as np

def suma(matriz, eje=None):
    return np.sum(matriz, axis=eje)

def resta(m1, m2):
    return np.subtract(m1, m2)

def multiplicacion(m1, m2):
    return np.multiply(m1, m2)

def division(m1, m2):
    return np.divide(m1, m2)

def logaritmo(matriz):
    return np.log(matriz)

def promedio(matriz, eje=None):
    return np.mean(matriz, axis=eje)

def desviacion_estandar(matriz, eje=None):
    return np.std(matriz, axis=eje)

print("Suma total:        ", suma(matriz_2d))
print("Suma por columnas: ", suma(matriz_2d, eje=0))
print("Suma por filas:    ", suma(matriz_2d, eje=1))
print("Promedio total:    ", promedio(matriz_2d))
print("Desv. estándar:    ", desviacion_estandar(matriz_2d))
# Out:
# Suma total:         59956.027080685686
# Suma por columnas:  [307.72876311 288.14547718 297.45521082 304.88413937 297.71444029
#  298.59021411 310.92622907 306.92721435 313.6264794  300.95420091
#  296.57524848 308.1589339  305.47294284 300.01958262 302.36711373
#  301.49526984 300.94119013 298.99668274 312.70155764 301.39458376
#  290.43995645 299.35177837 301.5869298  305.58473546 295.60623223
#  300.20552151 293.99698682 309.9948092  306.80408427 295.34681037
#  292.88969143 310.01829122 304.64076871 295.96481312 291.50185939
#  295.89045762 295.78658002 297.971146   291.65855571 296.74433574
#  303.52145408 288.71488419 299.51188118 299.00752263 316.82444848
#  300.51682441 301.37077641 310.7153556  305.41893788 300.98910258
#  285.10452499 308.59705364 298.30929497 304.09498171 291.53252773
#  307.43410495 313.74715478 307.75705927 294.674744   292.15377263
#  303.78276988 306.97419682 311.59742901 293.99096118 306.214166
#  289.34513422 305.20019535 300.43657643 305.55579136 304.99294464
#  305.4240086  293.2586213  306.35283771 292.40531519 304.19260648
#  299.29873857 295.47744895 307.39313835 297.91495761 295.79922114
#  294.38496272 300.73079001 291.1873103  311.6162791  304.17327643
#  291.73397742 294.98260858 304.40186986 294.39125554 302.58276235
#  291.91110146 303.0716826  293.33988221 292.45637514 288.35006129
#  311.44168049 299.06842124 298.6124431  299.87346951 299.68049333
#  296.36491404 302.46236105 289.1797262  305.03815136 298.57709254
#  295.70532624 279.65684639 294.06968306 299.91916615 303.8391473
#  298.31667943 289.27708919 293.61811667 293.47389247 305.91103521
#  305.51520686 306.97215782 304.94067712 304.11029903 299.72404394
#  284.97632522 297.3778922  301.42983964 303.20143554 294.35655056
#  307.76368258 309.42160351 293.89544016 304.88898431 299.89698767
#  304.65876923 290.32701469 285.69530564 292.00947234 297.80860886
#  305.14391198 304.90527569 295.09633687 304.44918267 307.93691553
#  298.8904051  307.59597154 290.32042454 286.72302569 293.73941597
#  296.92416658 300.03117119 297.10812462 288.96874851 309.90416407
#  304.78296738 301.03075996 302.39986638 300.48671948 299.09796333
#  298.94566895 308.04324836 299.41173673 303.41635822 302.60519235
#  303.95391883 298.79108999 290.5579845  300.85054938 305.16301816
#  295.58198719 305.8481644  294.10885075 307.06197246 293.36995702
#  291.43632291 296.81755209 293.51368732 290.50685331 290.19518409
#  293.51272946 298.6655506  299.01866048 310.80710978 302.1097485
#  108.77193368 106.58673615  94.98267413 102.18195877  98.46504662
#  100.53612415  97.45065577 108.63737107 101.36907793  98.51985032
#  102.25167312 100.56991027 103.41331126  97.51268637 105.19688583
#  103.24421802 101.80288704 107.44553906 104.38653657  93.0134107
#   93.24990753 101.4980424  104.16304787  97.6161465   97.27465704
#   98.86591482  95.88241766 103.0479017  105.12105375  98.87943514
#   94.25807842  97.37856072  98.59853311 102.8888015   97.28614782
#   95.79812449  99.77166106 102.33036333  98.78608492 107.41440986
#  103.68093816 104.29278429  96.59076029  97.92381654 101.73304621
#   99.2776976   97.52956765 104.17621029  96.27192231 102.8593812
#  101.82923031 101.06232356 101.64956834 100.36503646  96.6856206
#   99.06293139  98.83274317 101.2493124   98.07202459 103.98338785
#   96.9453231  100.58621977 101.66658846  96.00555544  98.59495039
#   92.99062788 101.05828367  90.47172823  91.87282897  92.58511388
#   98.0151193  100.27256683  96.46940883 100.6009044   94.85484767
#   97.63003879 100.87857461  99.8236083  100.67052734  96.60879783
#   98.6263783  100.48358309 103.68930071  98.98406418 100.85685489
#  100.59127418  96.18255152 100.54258803 101.35800542 105.93577851
#   99.85247967  96.6312474  100.08038897 101.30188046 100.83305627]
# Promedio total:     0.49963355900571405
# Desv. estándar:     0.28872964271155527

# %% [markdown]
# Archivo de Kaggle

# %%
import pandas as pd
import numpy as np

# Cargar el archivo
df_covid = pd.read_csv("covid_19_data.csv")

# Columnas numéricas disponibles
columnas_numericas = ["Confirmed", "Deaths", "Recovered"]

def elegir_columna(mensaje):
    print(f"\nColumnas disponibles: {columnas_numericas}")
    columna = input(mensaje)
    if columna not in columnas_numericas:
        print("Columna no válida")
        return None
    return columna

def suma_pd(df):
    columna = elegir_columna("Elige una columna para sumar: ")
    if columna:
        print(f"Suma de {columna}: {df[columna].sum()}")

def resta_pd(df):
    col1 = elegir_columna("Elige la primera columna: ")
    col2 = elegir_columna("Elige la segunda columna: ")
    if col1 and col2:
        print(f"\nResta {col1} - {col2}:")
        print((df[col1] - df[col2]).head())

def multiplicacion_pd(df):
    col1 = elegir_columna("Elige la primera columna: ")
    col2 = elegir_columna("Elige la segunda columna: ")
    if col1 and col2:
        print(f"\nMultiplicación {col1} * {col2}:")
        print((df[col1] * df[col2]).head())

def division_pd(df):
    col1 = elegir_columna("Elige la primera columna: ")
    col2 = elegir_columna("Elige la segunda columna: ")
    if col1 and col2:
        print(f"\nDivisión {col1} / {col2}:")
        print((df[col1] / df[col2]).head())

def logaritmo_pd(df):
    columna = elegir_columna("Elige una columna para logaritmo: ")
    if columna:
        print(f"\nLogaritmo de {columna}:")
        print(np.log(df[columna].replace(0, np.nan)).head())

def promedio_pd(df):
    columna = elegir_columna("Elige una columna para el promedio: ")
    if columna:
        print(f"Promedio de {columna}: {df[columna].mean()}")

def desviacion_estandar_pd(df):
    columna = elegir_columna("Elige una columna para desviación estándar: ")
    if columna:
        print(f"Desviación estándar de {columna}: {df[columna].std()}")

suma_pd(df_covid)
promedio_pd(df_covid)
desviacion_estandar_pd(df_covid)
# Out:
# Columnas disponibles: ['Confirmed', 'Deaths', 'Recovered']
# Suma de Confirmed: 26252051758.0
#
# Columnas disponibles: ['Confirmed', 'Deaths', 'Recovered']
# Promedio de Deaths: 2036.4032679674574
#
# Columnas disponibles: ['Confirmed', 'Deaths', 'Recovered']
# Columna no válida
